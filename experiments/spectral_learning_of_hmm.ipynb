# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from spectral_dagger.spectral.hankel import single_obs_basis
from spectral_dagger.utils.math import normalize
from spectral_dagger.hmm import HMM
from spectral_dagger.spectral import SpectralPSR

# %%
model_seed = 1
data_seed = np.random.randint(10000)
np.random.seed(model_seed)

n_states = 5
n_obs = 6

observations = range(n_obs)
states = range(n_states)

O = np.random.binomial(1, 0.5, (n_states, n_obs))
for row in O:
    if sum(row) == 0:
        row[:] = 1.0

O = normalize(O, ord=1, conservative=True)

T = np.random.binomial(1, 0.5, (n_states, n_states))
for row in T:
    if sum(row) == 0:
        row[:] = 1.0

T = normalize(T, ord=1, conservative=True)

init_dist = normalize(np.ones(n_states), ord=1, conservative=True)

hmm = HMM(observations, states, T, O, init_dist)

np.random.seed(data_seed)
print(hmm.sample_trajectory(10))

horizon = 3
test_samples = [hmm.sample_trajectory(horizon) for i in range(1000)]
results = []

estimators = ['string', 'prefix', 'substring', 'single']
sizes = np.linspace(1000, 10000, 5).astype('i')
dimensions = np.linspace(n_states, 2 * n_states, 5).astype('i')

for estimator in estimators:
    for m in dimensions:
        for n_samples in sizes:

            print "*" * 80
            samples = [hmm.sample_trajectory(horizon) for i in range(n_samples)]
            psr = SpectralPSR(hmm.observations)

            if m is None:
                m = hmm.n_states

            basis = None
            if estimator == 'single':
                basis = single_obs_basis(hmm.observations, True)
                estimator = 'substring'

            psr.fit(samples, m, estimator, basis=basis)

            llh = psr.get_log_likelihood(test_samples, base=2)
            print "$" * 80
            print "n_samples: ", n_samples
            perplexity = 2**(-llh)
            print "Perplexity: ", perplexity

            results.append(dict(
                n_samples=n_samples, estimator=estimator,
                dimension=m, perplexity=perplexity))

results = pd.DataFrame.from_records(results)
# Out:
# [3, 2, 3, 3, 3, 3, 1, 5, 3, 5]
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  1000
# Perplexity:  56.6468097089
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  3250
# Perplexity:  55.6792379784
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  5500
# Perplexity:  55.6453636049
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  7750
# Perplexity:  55.4550187569
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  10000
# Perplexity:  55.2095743504
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  1000
# Perplexity:  58.795956595
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  3250
# Perplexity:  54.076429003
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  5500
# Perplexity:  53.9736197868
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  7750
# Perplexity:  53.8364752328
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  10000
# Perplexity:  53.9529650491
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  1000
# Perplexity:  56.6022056831
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  3250
# Perplexity:  54.0562899417
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  5500
# Perplexity:  53.7777202172
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  7750
# Perplexity:  53.765039827
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  10000
# Perplexity:  53.2665213175
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  1000
# Perplexity:  60.1970041196
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  3250
# Perplexity:  54.0763388072
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  5500
# Perplexity:  53.3988376654
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  7750
# Perplexity:  53.4815847665
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  10000
# Perplexity:  53.1519980919
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  1000
# Perplexity:  71.4632965265
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  3250
# Perplexity:  54.0565529399
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  5500
# Perplexity:  56.7046844847
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  7750
# Perplexity:  53.0443835582
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  10000
# Perplexity:  53.4126688208
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  1000
# Perplexity:  61.5417191401
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  3250
# Perplexity:  54.3610832228
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  5500
# Perplexity:  53.923828879
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  7750
# Perplexity:  54.223985473
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  10000
# Perplexity:  54.1602502336
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  1000
# Perplexity:  55.33598246
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  3250
# Perplexity:  53.7477866747
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  5500
# Perplexity:  53.8786739213
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  7750
# Perplexity:  54.1167180796
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  10000
# Perplexity:  53.6137713492
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  1000
# Perplexity:  55.53495424
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  3250
# Perplexity:  54.1753159507
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  5500
# Perplexity:  53.748008453
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  7750
# Perplexity:  53.4219086452
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  10000
# Perplexity:  53.5393034686
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  1000
# Perplexity:  55.5884032627
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  3250
# Perplexity:  53.6171750299
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  5500
# Perplexity:  53.4150443607
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  7750
# Perplexity:  53.4647951604
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  10000
# Perplexity:  53.4315388595
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  1000
# Perplexity:  55.2996170171
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  3250
# Perplexity:  53.6977870861
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  5500
# Perplexity:  53.0422275036
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  7750
# Perplexity:  53.1663729103
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  10000
# Perplexity:  52.7479047887
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  1000
# Perplexity:  64.8175174303
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  3250
# Perplexity:  71.9141514698
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  5500
# Perplexity:  67.2946938583
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  7750
# Perplexity:  72.4315855227
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  10000
# Perplexity:  68.360028961
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  1000
# Perplexity:  60.8640095123
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  3250
# Perplexity:  56.5693905516
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  5500
# Perplexity:  53.3726859091
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  7750
# Perplexity:  53.837448586
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  10000
# Perplexity:  54.6389965201
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  1000
# Perplexity:  54.8854774994
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  3250
# Perplexity:  53.6575344863
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  5500
# Perplexity:  54.079209874
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  7750
# Perplexity:  54.301137032
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  10000
# Perplexity:  53.9110108042
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  1000
# Perplexity:  55.2827007712
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  3250
# Perplexity:  54.2659940611
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  5500
# Perplexity:  53.8206445729
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  7750
# Perplexity:  53.6281667392
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  10000
# Perplexity:  53.7890139305
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  1000
# Perplexity:  55.0927953116
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  3250
# Perplexity:  53.1949686616
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  5500
# Perplexity:  52.9297182835
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  7750
# Perplexity:  53.466973853
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  10000
# Perplexity:  53.2146131561
# ********************************************************************************
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  1000
# Perplexity:  73.9335816208
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  3250
# Perplexity:  78.2914587641
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  5500
# Perplexity:  87.1748443242
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  7750
# Perplexity:  72.4620840304
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  10000
# Perplexity:  76.3957459522
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  1000
# Perplexity:  64.8863211132
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  3250
# Perplexity:  54.3523451593
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  5500
# Perplexity:  54.2905208947
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  7750
# Perplexity:  55.0757716768
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  10000
# Perplexity:  54.1553845979
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  1000
# Perplexity:  56.8527300972
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  3250
# Perplexity:  54.4925375428
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  5500
# Perplexity:  54.1184317214
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  7750
# Perplexity:  54.7519217375
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  10000
# Perplexity:  54.1996022001
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  1000
# Perplexity:  59.2787750714
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  3250
# Perplexity:  54.69341819
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  5500
# Perplexity:  53.8076488488
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  7750
# Perplexity:  53.6584680001
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  10000
# Perplexity:  53.9592193315
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  1000
# Perplexity:  54.6019988299
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  3250
# Perplexity:  53.5791393178
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  5500
# Perplexity:  52.9030018674
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  7750
# Perplexity:  53.213341719
# ********************************************************************************
# Generating basis...
# Estimating Hankels...
# Performing SVD...
# Computing operators...
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# n_samples:  10000
# Perplexity:  53.1181845335

# %%
for estimator in estimators:
    for m in dimensions:
        data = results[
            (results['estimator'] == estimator)
            & (results['dimension'] == m)]
        linestyle = {'string': '-', 'prefix': '-.', 'substring': '--', 'single': ':'}[estimator]
        plt.plot(
            data['n_samples'], data['perplexity'], linestyle=linestyle, label='%s, Dim=%d' % (estimator, m))

plt.ylim((45, 80))
plt.legend(
    loc='center left', bbox_to_anchor=(1.05, 0.5), prop={'size': 10},
    handlelength=2.0, handletextpad=.5, shadow=False, frameon=False)
plt.gcf().subplots_adjust(wspace=0.3, left=0.1, right=0.75, bottom=0.15)

plt.show()
